# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %%
df=pd.read_csv('/content/California_Housing_CitiesAdded.csv')

# %%
df
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0                500001.0         1.2434          52        249          78.0
# 1                500001.0         1.1696          52        609         236.0
# 2                500001.0         7.8521          52       1668         225.0
# 3                500001.0         9.3959          52       3726         474.0
# 4                500001.0         7.8772          52       2990         379.0
# ...                   ...            ...         ...        ...           ...
# 16040            112500.0         2.5841          21       6445        1839.0
# 16041            112500.0         3.9110           4       3999        1079.0
# 16042            112500.0         3.4861          26       1453         251.0
# 16043            112500.0         3.4297          30       1233         214.0
# 16044            112500.0         2.3381          12         21           NaN
#
# ...

# %%
df['City'].unique()
# Out:
# array(['Alameda', 'Contra Costa', 'El Dorado', 'Los Angeles', 'Orange',
#        'Marin', 'Monterey', 'Riverside', 'San Bernardino', 'San Diego',
#        'San Francisco', 'San Luis Obispo', 'San Mateo', 'Santa Barbara',
#        'Santa Clara', 'Santa Cruz', 'Ventura', 'San Joaquin',
#        'Stanislaus', 'Sacramento', 'Napa', 'Placer', 'Solano', 'Sonoma',
#        'San Benito', 'Nevada', 'Fresno', 'Yolo', 'Mendocino', 'Kern',
#        'Mono', 'Tulare', 'Kings', 'Sutter', 'Tuolumne', 'Merced', 'Lake',
#        'Butte', 'Lassen', 'Amador', 'Inyo', 'Shasta', 'Humboldt', 'Yuba',
#        'Imperial', 'Madera', 'Del Norte', 'Tehama', 'Calaveras', 'Plumas',
#        'Siskiyou', 'Glenn', 'Colusa', nan], dtype=object)

# %%
# Mean value of houses in each city
df1=df.groupby(['City'])
df1['Median_House_Value'].mean().reset_index()
# Out:
#                City  Median_House_Value
# 0           Alameda       227337.046433
# 1            Amador       132679.166667
# 2             Butte       135917.241379
# 3         Calaveras       121144.444444
# 4            Colusa       116133.333333
# 5      Contra Costa       237056.919291
# 6         Del Norte       130600.000000
# 7         El Dorado       158025.014706
# 8            Fresno       148177.319588
# 9             Glenn       125000.000000
# 10         Humboldt       134688.235294
# 11         Imperial       135537.500000
# 12             Inyo       142857.142857
# 13             Kern       150166.666667
# 14            Kings       143257.142857
# 15             Lake       141266.666667
# 16           Lassen       150285.714286
# 17      Los Angeles       250541.879137
# 18           Madera       132533.333333
# 19            Marin       361477.801242
# 20        Mendocino       151813.636364
# 21           Merced       134571.428571
# ...

# %%
# # plotting the bar graph for median house value in each city
# fig = px.bar(df1, y='City', x='Median_House_Value',title='Median House Value in each city', width=1000, height=1000)
# # update x axis label
# fig.update_layout(xaxis_title='Median House Value')
# fig.show()

# %%
fig = px.histogram(df, x="City",title='Cities in California', width=1000, height=800)
fig.update_layout(xaxis_tickangle=-45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df1['Distance_to_coast'].mean().reset_index()
# Out:
#                City  Distance_to_coast
# 0           Alameda        8755.646633
# 1            Amador       76027.154220
# 2             Butte      171093.744690
# 3         Calaveras       89458.768602
# 4            Colusa      111377.737077
# 5      Contra Costa       10756.135993
# 6         Del Norte       18955.367129
# 7         El Dorado      125475.338599
# 8            Fresno      182200.565126
# 9             Glenn      132766.527400
# 10         Humboldt       11256.286076
# 11         Imperial       22028.474681
# 12             Inyo      286244.286814
# 13             Kern      116559.357284
# 14            Kings      142707.081843
# 15             Lake       63640.460835
# 16           Lassen      252493.315571
# 17      Los Angeles       22220.177083
# 18           Madera      154238.408667
# 19            Marin        5834.055172
# 20        Mendocino       29761.518115
# 21           Merced      109735.666810
# 22             Mono      217753.656886
# ...

# %%
# lets see median house age vs median house value
fig = px.scatter(df, x="Median_House_Value", y="Median_Age", hover_name="City",title='Median House Value vs Median Age', width=1000, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# center of mass of scatter graph

# %%
# correlation  between median income and median value of houses
fig=px.scatter(df,'Median_Income','Median_House_Value')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# population Vs Median_Income
fig = px.scatter(df,x='Population', y='Median_House_Value')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['Price_block']=df['Median_House_Value']*df['Households']
fig = px.scatter(df, x="Price_block", y="Tot_Rooms", hover_name="City",title='Price Block vs Total Bedrooms', width=1000, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
